# %%
using AbstractTrees
using D3Trees
using HTTP
using Sockets
using JSON

# Fix Jupyter issue that prevents logged stack traces to display correctly 
# https://github.com/JuliaLang/IJulia.jl/pull/1045
import Logging: ConsoleLogger
logger = ConsoleLogger(Base.stderr)
Base.CoreLogging.global_logger(logger)
# Out:
# Base.CoreLogging.SimpleLogger(IJulia.IJuliaStdio{Base.PipeEndpoint}(IOContext(Base.PipeEndpoint(RawFD(45) open, 0 bytes waiting))), Info, Dict{Any, Int64}())

# %%
include(joinpath(dirname(dirname(pathof(D3Trees))), "test", "binaryAbstractTrees.jl"))

# %% [markdown]
# # Lazy loading infinite tree
#  - F12 to see the javascript logging
#  - If it does not appear on its own, run any cell below to view the Julia log

# %%
# Tree with very large depth
ldroot = LimitedDepthTree()

# max_expand_depth controls the initial generation of the tree, 
# through the `children` AbstractTrees.jl interface
D3Tree(ldroot, max_expand_depth=1, init_expand=1)
# Out:
# 1 (d=0) -> [2, 3]
# ├──2 (d=1) -> [4, 5]
# └──3 (d=1) -> [6, 7]
# ┌ Info: Handling treeviswDXOzU8O - 2 req: HTTP.Messages.Request:
# │ """
# │ GET /api/d3trees/v1/tree/treeviswDXOzU8O/2 HTTP/1.1
# │ Host: localhost:16370
# │ Connection: keep-alive
# │ sec-ch-ua: " Not;A Brand";v="99", "Microsoft Edge";v="103", "Chromium";v="103"
# │ DNT: 1
# │ sec-ch-ua-mobile: ?0
# │ User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.53 Safari/537.36 Edg/103.0.1264.37
# │ sec-ch-ua-platform: "Windows"
# │ Accept: */*
# │ Origin: http://localhost:8989
# │ Sec-Fetch-Site: same-site
# │ Sec-Fetch-Mode: cors
# │ Sec-Fetch-Dest: empty
# │ Referer: http://localhost:8989/
# │ Accept-Encoding: gzip, deflate, br
# │ Accept-Language: en-US,en;q=0.9,cs;q=0.8
# │
# └ """
# ┌ Info: HTTP.Messages.Request:
# │ """
# │ GET /api/d3trees/v1/tree/treeviswDXOzU8O/2 HTTP/1.1
# │ Host: localhost:16370
# │ Connection: keep-alive
# │ sec-ch-ua: " Not;A Brand";v="99", "Microsoft Edge";v="103", "Chromium";v="103"
# │ DNT: 1
# │ sec-ch-ua-mobile: ?0
# │ User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.53 Safari/537.36 Edg/103.0.1264.37
# │ sec-ch-ua-platform: "Windows"
# │ Accept: */*
# │ Origin: http://localhost:8989
# │ Sec-Fetch-Site: same-site
# │ Sec-Fetch-Mode: cors
# │ Sec-Fetch-Dest: empty
# │ Referer: http://localhost:8989/
# │ Accept-Encoding: gzip, deflate, br
# │ Accept-Language: en-US,en;q=0.9,cs;q=0.8
# │
# └ """
# ┌ Info: HTTP.Messages.Response:
# │ """
# │ HTTP/1.1 200 OK
# │ Access-Control-Allow-Origin: *
# │
# └ "{\"children\":[[4,5],[],[],[7,8],[],[]],\"tooltip\":[\"4 (d=2) -> [8, 9]\",\"8 (d=3) -> [16, 17]\",\"9 (d=3) -> [18, 19]\",\"5 (d=2) -> [10, 11]\",\"10 (d=3) -> [20, 21]\",\"11 (d=3) -> [22, 23]\"],\"link_style\":[\"\",\"\",\"\",\"\",\"\",\"\"],\"title\":\"Julia D3Tree\",\"unexpanded_children\":[4,5,8,7],\"text\":[\"4 (d=2) -> [8, 9]\",\"8 (d=3) -> [16, 17]\",\"9 (d=3) -> [18, 19]\",\"5 (d=2) -> [10, 11]\",\"10 (d=3) -> [20, 21]\",\"11 (d=3) -> [22, 23]\"],\"options\":{},\"root_children\":[3,6],\"root_id\":1,\"style\":[\"\",\"\",\"\",\"\",\"\",\"\"]}""""
# ┌ Info: Handling treeviswDXOzU8O - 2 req: HTTP.Messages.Request:
# │ """
# │ GET /api/d3trees/v1/tree/treeviswDXOzU8O/2 HTTP/1.1
# │ Host: localhost:16370
# │ Connection: keep-alive
# │ sec-ch-ua: " Not;A Brand";v="99", "Microsoft Edge";v="103", "Chromium";v="103"
# │ DNT: 1
# │ sec-ch-ua-mobile: ?0
# │ User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.53 Safari/537.36 Edg/103.0.1264.37
# │ sec-ch-ua-platform: "Windows"
# │ Accept: */*
# │ Origin: http://localhost:8989
# │ Sec-Fetch-Site: same-site
# │ Sec-Fetch-Mode: cors
# │ Sec-Fetch-Dest: empty
# │ Referer: http://localhost:8989/
# │ Accept-Encoding: gzip, deflate, br
# │ Accept-Language: en-US,en;q=0.9,cs;q=0.8
# │
# └ """
# ┌ Error: [TREE] Could not expand tree:
# └ @ D3Trees ~/projects/D3Trees.jl/src/server.jl:113
# ┌ LogLevel(1999): handle_connection handler error
# │   exception =
# │    AssertionError: Node at index 2 is already expanded!
# │    Stacktrace:
# │      [1] expand_node!(t::D3Tree, ind::Int64, max_expand_depth::Int64)
# │        @ D3Trees ~/projects/D3Trees.jl/src/D3Trees.jl:215
# │      [2] process_node_expand_request(tree_data::Dict{String, D3Tree}, div_id::String, subtree_root_id::Int64, depth::Int64)
# │        @ D3Trees ~/projects/D3Trees.jl/src/server.jl:109
# │      [3] handle_subtree_request(req::HTTP.Messages.Request)
# │        @ D3Trees ~/projects/D3Trees.jl/src/server.jl:126
# │      [4] (::HTTP.Handlers.Router{typeof(HTTP.Handlers.default404), typeof(HTTP.Handlers.default405)})(req::HTTP.Messages.Request)
# │        @ HTTP.Handlers ~/.julia/packages/HTTP/S5kNN/src/Handlers.jl:429
# │      [5] (::D3Trees.var"#15#16"{HTTP.Handlers.Router{typeof(HTTP.Handlers.default404), typeof(HTTP.Handlers.default405)}})(req::HTTP.Messages.Request)
# │        @ D3Trees ~/projects/D3Trees.jl/src/server.jl:79
# │      [6] #17
# │        @ ~/projects/D3Trees.jl/src/server.jl:100 [inlined]
# │      [7] (::HTTP.Handlers.var"#1#2"{D3Trees.var"#17#18"{D3Trees.var"#15#16"{HTTP.Handlers.Router{typeof(HTTP.Handlers.default404), typeof(HTTP.Handlers.default405)}}}})(stream::HTTP.Streams.Stream{HTTP.Messages.Request, HTTP.ConnectionPool.Connection})
# │        @ HTTP.Handlers ~/.julia/packages/HTTP/S5kNN/src/Handlers.jl:58
# │      [8] #invokelatest#2
# │        @ ./essentials.jl:716 [inlined]
# │      [9] invokelatest
# │        @ ./essentials.jl:714 [inlined]
# │     [10] handle_connection(f::Function, c::HTTP.ConnectionPool.Connection, listener::HTTP.Servers.Listener{Nothing, Sockets.TCPServer}, readtimeout::Int64, access_log::Nothing)
# │        @ HTTP.Servers ~/.julia/packages/HTTP/S5kNN/src/Servers.jl:445
# │     [11] (::HTTP.Servers.var"#15#16"{HTTP.Handlers.var"#1#2"{D3Trees.var"#17#18"{D3Trees.var"#15#16"{HTTP.Handlers.Router{typeof(HTTP.Handlers.default404), typeof(HTTP.Handlers.default405)}}}}, HTTP.Servers.Listener{Nothing, Sockets.TCPServer}, Set{HTTP.ConnectionPool.Connection}, Int64, Nothing, Base.Semaphore, HTTP.ConnectionPool.Connection})()
# │        @ HTTP.Servers ./task.jl:423
# └ @ HTTP.Servers ~/.julia/packages/HTTP/S5kNN/src/Servers.jl:459
# ┌ Info: Handling treeviswDXOzU8O - 5 req: HTTP.Messages.Request:
# │ """
# │ GET /api/d3trees/v1/tree/treeviswDXOzU8O/5 HTTP/1.1
# │ Host: localhost:16370
# │ Connection: keep-alive
# │ sec-ch-ua: " Not;A Brand";v="99", "Microsoft Edge";v="103", "Chromium";v="103"
# │ DNT: 1
# │ sec-ch-ua-mobile: ?0
# │ User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.53 Safari/537.36 Edg/103.0.1264.37
# │ sec-ch-ua-platform: "Windows"
# │ Accept: */*
# │ Origin: http://localhost:8989
# │ Sec-Fetch-Site: same-site
# │ Sec-Fetch-Mode: cors
# │ Sec-Fetch-Dest: empty
# │ Referer: http://localhost:8989/
# │ Accept-Encoding: gzip, deflate, br
# │ Accept-Language: en-US,en;q=0.9,cs;q=0.8
# │
# └ """
# ┌ Info: HTTP.Messages.Request:
# │ """
# │ GET /api/d3trees/v1/tree/treeviswDXOzU8O/5 HTTP/1.1
# │ Host: localhost:16370
# │ Connection: keep-alive
# │ sec-ch-ua: " Not;A Brand";v="99", "Microsoft Edge";v="103", "Chromium";v="103"
# │ DNT: 1
# │ sec-ch-ua-mobile: ?0
# │ User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.53 Safari/537.36 Edg/103.0.1264.37
# │ sec-ch-ua-platform: "Windows"
# │ Accept: */*
# │ Origin: http://localhost:8989
# │ Sec-Fetch-Site: same-site
# │ Sec-Fetch-Mode: cors
# │ Sec-Fetch-Dest: empty
# │ Referer: http://localhost:8989/
# │ Accept-Encoding: gzip, deflate, br
# │ Accept-Language: en-US,en;q=0.9,cs;q=0.8
# │
# └ """

# %%
println("Async log:")
# Out:
# Async log:
# ┌ Info: HTTP.Messages.Response:
# │ """
# │ HTTP/1.1 200 OK
# │ Access-Control-Allow-Origin: *
# │
# └ "{\"children\":[[10,11],[],[],[13,14],[],[]],\"tooltip\":[\"16 (d=4) -> [32, 33]\",\"32 (d=5) -> [64, 65]\",\"33 (d=5) -> [66, 67]\",\"17 (d=4) -> [34, 35]\",\"34 (d=5) -> [68, 69]\",\"35 (d=5) -> [70, 71]\"],\"link_style\":[\"\",\"\",\"\",\"\",\"\",\"\"],\"title\":\"Julia D3Tree\",\"unexpanded_children\":[14,10,11,13],\"text\":[\"16 (d=4) -> [32, 33]\",\"32 (d=5) -> [64, 65]\",\"33 (d=5) -> [66, 67]\",\"17 (d=4) -> [34, 35]\",\"34 (d=5) -> [68, 69]\",\"35 (d=5) -> [70, 71]\"],\"options\":{},\"root_children\":[9,12],\"root_id\":4,\"style\":[\"\",\"\",\"\",\"\",\"\",\"\"]}""""
# ┌ Info: Handling treeviswDXOzU8O - 11 req: HTTP.Messages.Request:
# │ """
# │ GET /api/d3trees/v1/tree/treeviswDXOzU8O/11 HTTP/1.1
# │ Host: localhost:16370
# │ Connection: keep-alive
# │ sec-ch-ua: " Not;A Brand";v="99", "Microsoft Edge";v="103", "Chromium";v="103"
# │ DNT: 1
# │ sec-ch-ua-mobile: ?0
# │ User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.53 Safari/537.36 Edg/103.0.1264.37
# │ sec-ch-ua-platform: "Windows"
# │ Accept: */*
# │ Origin: http://localhost:8989
# │ Sec-Fetch-Site: same-site
# │ Sec-Fetch-Mode: cors
# │ Sec-Fetch-Dest: empty
# │ Referer: http://localhost:8989/
# │ Accept-Encoding: gzip, deflate, br
# │ Accept-Language: en-US,en;q=0.9,cs;q=0.8
# │
# └ """
# ┌ Info: HTTP.Messages.Request:
# │ """
# │ GET /api/d3trees/v1/tree/treeviswDXOzU8O/11 HTTP/1.1
# │ Host: localhost:16370
# │ Connection: keep-alive
# │ sec-ch-ua: " Not;A Brand";v="99", "Microsoft Edge";v="103", "Chromium";v="103"
# │ DNT: 1
# │ sec-ch-ua-mobile: ?0
# │ User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.53 Safari/537.36 Edg/103.0.1264.37
# │ sec-ch-ua-platform: "Windows"
# │ Accept: */*
# │ Origin: http://localhost:8989
# │ Sec-Fetch-Site: same-site
# │ Sec-Fetch-Mode: cors
# │ Sec-Fetch-Dest: empty
# │ Referer: http://localhost:8989/
# │ Accept-Encoding: gzip, deflate, br
# │ Accept-Language: en-US,en;q=0.9,cs;q=0.8
# │
# └ """
# ┌ Info: HTTP.Messages.Response:
# │ """
# │ HTTP/1.1 200 OK
# │ Access-Control-Allow-Origin: *
# │
# └ "{\"children\":[[16,17],[],[],[19,20],[],[]],\"tooltip\":[\"64 (d=6) -> [128, 129]\",\"128 (d=7) -> [256, 257]\",\"129 (d=7) -> [258, 259]\",\"65 (d=6) -> [130, 131]\",\"130 (d=7) -> [260, 261]\",\"131 (d=7) -> [262, 263]\"],\"link_style\":[\"\",\"\",\"\",\"\",\"\",\"\"],\"title\":\"Julia D3Tree\",\"unexpanded_children\":[19,20,17,16],\"text\":[\"64 (d=6) -> [128, 129]\",\"128 (d=7) -> [256, 257]\",\"129 (d=7) -> [258, 259]\",\"65 (d=6) -> [130, 131]\",\"130 (d=7) -> [260, 261]\",\"131 (d=7) -> [262, 263]\"],\"options\":{},\"root_children\":[15,18],\"root_id\":10,\"style\":[\"\",\"\",\"\",\"\",\"\",\"\"]}""""
# ┌ Info: Handling treeviswDXOzU8O - 17 req: HTTP.Messages.Request:
# │ """
# │ GET /api/d3trees/v1/tree/treeviswDXOzU8O/17 HTTP/1.1
# │ Host: localhost:16370
# │ Connection: keep-alive
# │ sec-ch-ua: " Not;A Brand";v="99", "Microsoft Edge";v="103", "Chromium";v="103"
# │ DNT: 1
# │ sec-ch-ua-mobile: ?0
# │ User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.53 Safari/537.36 Edg/103.0.1264.37
# │ sec-ch-ua-platform: "Windows"
# │ Accept: */*
# │ Origin: http://localhost:8989
# │ Sec-Fetch-Site: same-site
# │ Sec-Fetch-Mode: cors
# │ Sec-Fetch-Dest: empty
# │ Referer: http://localhost:8989/
# │ Accept-Encoding: gzip, deflate, br
# │ Accept-Language: en-US,en;q=0.9,cs;q=0.8
# │
# └ """
# ┌ Info: HTTP.Messages.Request:
# │ """
# │ GET /api/d3trees/v1/tree/treeviswDXOzU8O/17 HTTP/1.1
# │ Host: localhost:16370
# │ Connection: keep-alive
# │ sec-ch-ua: " Not;A Brand";v="99", "Microsoft Edge";v="103", "Chromium";v="103"
# │ DNT: 1
# │ sec-ch-ua-mobile: ?0
# │ User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.53 Safari/537.36 Edg/103.0.1264.37
# │ sec-ch-ua-platform: "Windows"
# │ Accept: */*
# │ Origin: http://localhost:8989
# │ Sec-Fetch-Site: same-site
# │ Sec-Fetch-Mode: cors
# │ Sec-Fetch-Dest: empty
# │ Referer: http://localhost:8989/
# │ Accept-Encoding: gzip, deflate, br
# │ Accept-Language: en-US,en;q=0.9,cs;q=0.8
# │
# └ """
# ┌ Info: HTTP.Messages.Response:
# │ """
# │ HTTP/1.1 200 OK
# │ Access-Control-Allow-Origin: *
# │
# └ "{\"children\":[[22,23],[],[],[25,26],[],[]],\"tooltip\":[\"256 (d=8) -> [512, 513]\",\"512 (d=9) -> [1024, 1025]\",\"513 (d=9) -> [1026, 1027]\",\"257 (d=8) -> [514, 515]\",\"514 (d=9) -> [1028, 1029]\",\"515 (d=9) -> [1030, 1031]\"],\"link_style\":[\"\",\"\",\"\",\"\",\"\",\"\"],\"title\":\"Julia D3Tree\",\"unexpanded_children\":
HTTP/1.1
# │ Host: localhost:16370
# │ Connection: keep-alive
# │ sec-ch-ua: " Not;A Brand";v="99", "Microsoft Edge";v="103", "Chromium";v="103"
# │ DNT: 1
# │ sec-ch-ua-mobile: ?0
# │ User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.53 Safari/537.36 Edg/103.0.1264.37
# │ sec-ch-ua-platform: "Windows"
# │ Accept: */*
# │ Origin: http://localhost:8989
# │ Sec-Fetch-Site: same-site
# │ Sec-Fetch-Mode: cors
# │ Sec-Fetch-Dest: empty
# │ Referer: http://localhost:8989/
# │ Accept-Encoding: gzip, deflate, br
# │ Accept-Language: en-US,en;q=0.9,cs;q=0.8
# │
# └ """
# ┌ Info: HTTP.Messages.Response:
# │ """
# │ HTTP/1.1 200 OK
# │ Access-Control-Allow-Origin: *
# │
# └ "{\"children\":[[52,53],[],[],[55,56],[],[]],\"tooltip\":[\"6 (d=2) -> [12, 13]\",\"12 (d=3) -> [24, 25]\",\"13 (d=3) -> [26, 27]\",\"7 (d=2) -> [14, 15]\",\"14 (d=3) -> [28, 29]\",\"15 (d=3) -> [30, 31]\"],\"link_style\":[\"\",\"\",\"\",\"\",\"\",\"\"],\"title\":\"Julia D3Tree\",\"unexpanded_children\":[55,53,56,52],\"text\":[\"6 (d=2) -> [12, 13]\",\"12 (d=3) -> [24, 25]\",\"13 (d=3) -> [26, 27]\",\"7 (d=2) -> [14, 15]\",\"14 (d=3) -> [28, 29]\",\"15 (d=3) -> [30, 31]\"],\"options\":{},\"root_children\":[51,54],\"root_id\":2,\"style\":[\"\",\"\",\"\",\"\",\"\",\"\"]}""""
# ┌ Info: Handling treeviswDXOzU8O - 57 req: HTTP.Messages.Request:
# │ """
# │ GET /api/d3trees/v1/tree/treeviswDXOzU8O/57 HTTP/1.1
# │ Host: localhost:16370
# │ Connection: keep-alive
# │ sec-ch-ua: " Not;A Brand";v="99", "Microsoft Edge";v="103", "Chromium";v="103"
# │ DNT: 1
# │ sec-ch-ua-mobile: ?0
# │ User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.53 Safari/537.36 Edg/103.0.1264.37
# │ sec-ch-ua-platform: "Windows"
# │ Accept: */*
# │ Origin: http://localhost:8989
# │ Sec-Fetch-Site: same-site
# │ Sec-Fetch-Mode: cors
# │ Sec-Fetch-Dest: empty
# │ Referer: http://localhost:8989/
# │ Accept-Encoding: gzip, deflate, br
# │ Accept-Language: en-US,en;q=0.9,cs;q=0.8
# │
# └ """
# ┌ Info: HTTP.Messages.Request:
# │ """
# │ GET /api/d3trees/v1/tree/treeviswDXOzU8O/57 HTTP/1.1
# │ Host: localhost:16370
# │ Connection: keep-alive
# │ sec-ch-ua: " Not;A Brand";v="99", "Microsoft Edge";v="103", "Chromium";v="103"
# │ DNT: 1
# │ sec-ch-ua-mobile: ?0
# │ User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.53 Safari/537.36 Edg/103.0.1264.37
# │ sec-ch-ua-platform: "Windows"
# │ Accept: */*
# │ Origin: http://localhost:8989
# │ Sec-Fetch-Site: same-site
# │ Sec-Fetch-Mode: cors
# │ Sec-Fetch-Dest: empty
# │ Referer: http://localhost:8989/
# │ Accept-Encoding: gzip, deflate, br
# │ Accept-Language: en-US,en;q=0.9,cs;q=0.8
# │
# └ """
# ┌ Info: HTTP.Messages.Response:
# │ """
# │ HTTP/1.1 200 OK
# │ Access-Control-Allow-Origin: *
# │
# └ "{\"children\":[[58,59],[],[],[61,62],[],[]],\"tooltip\":[\"30 (d=4) -> [60, 61]\",\"60 (d=5) -> [120, 121]\",\"61 (d=5) -> [122, 123]\",\"31 (d=4) -> [62, 63]\",\"62 (d=5) -> [124, 125]\",\"63 (d=5) -> [126, 127]\"],\"link_style\":[\"\",\"\",\"\",\"\",\"\",\"\"],\"title\":\"Julia D3Tree\",\"unexpanded_children\":[58,62,59,61],\"text\":[\"30 (d=4) -> [60, 61]\",\"60 (d=5) -> [120, 121]\",\"61 (d=5) -> [122, 123]\",\"31 (d=4) -> [62, 63]\",\"62 (d=5) -> [124, 125]\",\"63 (d=5) -> [126, 127]\"],\"options\":{},\"root_children\":[57,60],\"root_id\":56,\"style\":[\"\",\"\",\"\",\"\",\"\",\"\"]}""""
# ┌ Info: Handling treeviswDXOzU8O - 50 req: HTTP.Messages.Request:
# │ """
# │ GET /api/d3trees/v1/tree/treeviswDXOzU8O/50 HTTP/1.1
# │ Host: localhost:16370
# │ Connection: keep-alive
# │ sec-ch-ua: " Not;A Brand";v="99", "Microsoft Edge";v="103", "Chromium";v="103"
# │ DNT: 1
# │ sec-ch-ua-mobile: ?0
# │ User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.53 Safari/537.36 Edg/103.0.1264.37
# │ sec-ch-ua-platform: "Windows"
# │ Accept: */*
# │ Origin: http://localhost:8989
# │ Sec-Fetch-Site: same-site
# │ Sec-Fetch-Mode: cors
# │ Sec-Fetch-Dest: empty
# │ Referer: http://localhost:8989/
# │ Accept-Encoding: gzip, deflate, br
# │ Accept-Language: en-US,en;q=0.9,cs;q=0.8
# │
# └ """
# ┌ Info: HTTP.Messages.Request:
# │ """
# │ GET /api/d3trees/v1/tree/treeviswDXOzU8O/50 HTTP/1.1
# │ Host: localhost:16370
# │ Connection: keep-alive
# │ sec-ch-ua: " Not;A Brand";v="99", "Microsoft Edge";v="103", "Chromium";v="103"
# │ DNT: 1
# │ sec-ch-ua-mobile: ?0
# │ User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.5060.53 Safari/537.36 Edg/103.0.1264.37
# │ sec-ch-ua-platform: "Windows"
# │ Accept: */*
# │ Origin: http://localhost:8989
# │ Sec-Fetch-Site: same-site
# │ Sec-Fetch-Mode: cors
# │ Sec-Fetch-Dest: empty
# │ Referer: http://localhost:8989/
# │ Accept-Encoding: gzip, deflate, br
# │ Accept-Language: en-US,en;q=0.9,cs;q=0.8
# │
# └ """
# ┌ Info: HTTP.Messages.Response:
# │ """
# │ HTTP/1.1 200 OK
# │ Access-Control-Allow-Origin: *
# │
# └ "{\"children\":[[64,65],[],[],[67,68],[],[]],\"tooltip\":[\"262148 (d=18) -> [524296, 524297]\",\"524296 (d=19) -> [1048592, 1048593]\",\"524297 (d=19) -> [1048594, 1048595]\",\"262149 (d=18) -> [524298, 524299]\",\"524298 (d=19) -> [1048596, 1048597]\",\"524299 (d=19) -> [1048598, 1048599]\"],\"link_style\":[\"\",\"\",\"\",\"\",\"\",\"\"],\"title\":\"Julia D3Tree\",\"unexpanded_children\":[64,68,67,65],\"text\":[\"262148 (d=18) -> [524296, 524297]\",\"524296 (d=19) -> [1048592, 1048593]\",\"524297 (d=19) -> [1048594, 1048595]\",\"262149 (d=18) -> [524298, 524299]\",\"524298 (d=19) -> [1048596, 1048597]\",\"524299 (d=19) -> [1048598, 1048599]\"],\"options\":{},\"root_children\":[63,66],\"root_id\":49,\"style\":[\"\",\"\",\"\",\"\",\"\",\"\"]}""""
